# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('multiclass_diabetes.csv')
data
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6       81             97             12       22  27.5
# 1             3      102             61             49      249  21.2
# 2             7      117             54             33        9  21.9
# 3             4      131             86             41      245  38.6
# 4             6      106             81             31       99  34.7
# ..          ...      ...            ...            ...      ...   ...
# 95            9      181             52             48      121  40.7
# 96            8      129             67             45      132  40.6
# 97            6      182             74             42      162  30.7
# 98            8       71             91             39      214  29.2
# 99            7      198             80             46      220  25.4
#
#     DiabetesPedigreeFunction  Age RiskLevel
# 0                      0.235   31      High
# ...

# %%
data['RiskLevel'].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %%
data['RiskLevel'] = data['RiskLevel'].map({'High':1,'Medium':2, 'Low':3})

# %%
data['RiskLevel'].dtype
# Out:
# dtype('int64')

# %%
X = data.iloc[:,:-1]
Y = data['RiskLevel']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# C:\Users\hj101658\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict = model.predict(X_test)

# %%
print(model.predict([[7,198,80,46,220,25.4,1.894,23]]))
# Out:
# [2]
# C:\Users\hj101658\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(model.predict([[7,198,80,46,220,25.4,1.894,23]]))
